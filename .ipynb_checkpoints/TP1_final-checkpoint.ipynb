# %% [markdown]
# TP1: Introduction aux opérateurs de base de PyTorch (Décomposition d'une image à l'aide d'ondelette de Haar et autres traitement)
# ============
#
# Introduction au sujet
# ------
#
# L'objectif de ce sujet est d'étudier des opérateurs de base de Pytorch au travers de la décomposition par ondelette de Haar d'une image. La décomposition d'une image en ondelette est notamment utilisé en compression dans des formats de fichier tel que JPEG2000. Nous travaillerons sur une photographie d'[Ada Lovelace](https://fr.wikipedia.org/wiki/Ada_Lovelace) qui vous est fournis.
#
# Le code est à écrire en python3 à la suite des questions dans ce fichier. Vous appuierez soit sur le bouton *run cell*, soit sur les touches *Ctrl-Entrée*, à l’intérieur de la zone de saisie, pour lancer l'exécution de vos commandes. Si la commande est en cours d’exécution une étoile apparaît à côté de la zone de saisie de la commande : In [\*]. Une fois le calcul achevé, l'étoile est remplacée par le numéro du run permettant de retrouver par la suite dans quel ordre ont été lancés chaque bloc.
#
# N'hésitez pas à regarder régulièrement la documentation de ces librairies, des exemples d'utilisation accompagnent généralement l'explication de chaque fonction.
#
# Langage utilisé:
# - Python 3: https://docs.python.org/3/
#
# Librairie de math:
# - Numpy: https://docs.scipy.org/doc/numpy/reference/
# - Scipy: https://docs.scipy.org/doc/scipy/reference/
#
# Librairie d'affichage de données:
# - Matplotilb: https://matplotlib.org/contents.html
#
# Librairie Pytorch:
# - PyTorch: https: https://pytorch.org/docs/stable/
#
# Commencez par importer les librairies nécessaires au TP.

# %%
# Import Torch
import torch
import torch.nn as nn

# Import numpy et matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# 0 - Introduction au notebook jupyter
# ----------

# %% [markdown]
# Exécutez la ligne suivante en vous plaçant dans la cellule et en appuyant sur *Ctrl+Entrée*.

# %%
a=1
print(a)
# Out:
# 1

# %% [markdown]
# Lancez la ligne suivante plusieurs fois.

# %%
a += 1
print(a)
# Out:
# 10

# %% [markdown]
# Relancez le premier bloc définissant la variable `a` puis lancez le bloc suivant (remarquez bien les valeurs après In [\*] ):

# %%
print(a)
# Out:
# 1

# %% [markdown]
# Vous pouvez utiliser l'aide à la complétion avec tab. Testez avec la fonction numpy.random.randn.

# %%
A= np.random.randn(100,4,2)
A
# Out:
# array([[[-9.08005338e-01, -2.35355869e-01],
#         [ 5.47810956e-01,  6.99471200e-01],
#         [ 1.59870866e+00,  3.25343411e-01],
#         [ 8.61896238e-01, -3.60918844e-01]],
#
#        [[-1.13987529e+00, -2.30025675e-01],
#         [ 2.92603873e-01,  1.05575244e+00],
#         [ 3.55588651e-01, -1.16172215e-01],
#         [ 1.47357702e+00, -1.58608703e+00]],
#
#        [[-1.04106870e+00,  2.87517569e-01],
#         [-1.04575412e+00, -7.00133752e-01],
#         [ 6.09609222e-01, -1.14756690e+00],
#         [ 1.13650682e+00, -7.08271701e-01]],
#
#        [[ 1.20396304e+00,  5.58804166e-01],
#         [-1.72587141e+00,  1.67739236e+00],
#         [-3.48913100e-01,  1.95814585e-01],
#         [-1.19770546e+00, -6.70054957e-01]],
#
#        [[ 2.68353681e-01,  2.75742236e+00],
#         [ 1.81507210e-01,  1.05355943e+00],
#         [-6.24525249e-02, -2.13047554e+00],
#         [ 1.39248885e-01,  2.70489723e-01]],
#
#        [[ 2.39836002e-01, -1.91276109e+00],
#         [ 2.69203136e+00, -1.18904404e+00],
#         [ 9.07313493e-01,  8.79344533e-01],
#         [ 1.81646405e+00, -1.75069472e+00]],
#
#        [[ 3.44218516e-01, -6.42144341e-01],
#         [-1.44365289e+00,  2.22472255e+00],
#         [ 2.70755467e-02, -4.50013731e-01],
#         [-1.07006510e+00, -5.02795031e-01]],
#
#        [[-1.53939661e+00, -4.73343042e-01],
#         [ 7.81034687e-01, -8.13274537e-02],
#         [ 1.51418676e-01, -3.68238364e-01],
#         [ 1.67741488e+00,  3.95349042e-01]],
#
#        [[ 2.44905017e-01, -2.14720782e-01],
#         [-9.13478756e-01,  1.17865927e+00],
#         [-9.90219286e-01, -1.41769539e-02],
#         [ 8.87183879e-01,  6.25881214e-01]],
#
#        [[ 1.50323231e+00, -1.12064204e-01],
#         [-2.13615669e+00, -1.13749264e-02],
#         [-1.27062533e+00,  1.93336756e+00],
#         [-1.07287103e+00, -7.94245353e-01]],
#
#        [[-2.47488210e-01,  2.53698821e+00],
#         [ 1.75350202e+00, -5.26377210e-01],
#         [ 1.29223917e+00, -2.30162610e+00],
#         [ 4.52691020e-01, -2.51043493e-01]],
#
#        [[ 2.35762504e+00,  1.55244416e+00],
#         [-8.03618222e-01,  1.24780788e+00],
#         [ 6.77064993e-01, -1.89775595e-01],
#         [-2.30700053e-01, -1.92665266e+00]],
#
#        [[ 7.66079359e-01, -3.85356659e-02],
#         [ 1.31262505e-01, -1.92793968e+00],
#         [-1.18064830e+00, -6.68825938e-01],
#         [-2.42073407e-01, -1.10276207e+00]],
#
#        [[-3.34216928e-01,  4.47055983e-01],
#         [-1.10526058e-01, -1.38770477e-01],
#         [ 5.08565344e-01, -6.36207378e-01],
#         [-3.86125562e-01, -8.08567131e-01]],
#
#        [[-1.33241772e-01,  1.84468496e+00],
#         [ 3.59547694e-01, -1.83638314e-01],
#         [-6.02242729e-02, -8.69138059e-01],
#         [-2.39167290e-01, -8.42775643e-01]],
#
#        [[ 6.74608983e-01, -6.52331912e-01],
#         [ 1.31304525e+00, -3.46918674e-01],
#         [ 2.48717437e-01,  9.30648256e-01],
#         [ 8.73899055e-02, -7.92826993e-01]],
#
#        [[ 1.40448725e+00,  1.03859097e+00],
#         [-1.80193590e+00, -1.20721133e+00],
#         [-1.73216443e-01, -5.96948539e-01],
#         [-4.34756498e-01,  2.56081357e-01]],
#
#        [[ 5.21384993e-01,  1.60049007e+00],
#         [-4.69617158e-01,  4.07647609e-01],
#         [ 1.53897190e-01,  6.51996343e-01],
#         [-2.58359334e-01, -2.79327795e+00]],
#
#        [[ 3.05835337e-01,  1.65765735e-01],
#         [ 4.88510434e-01,  5.28879750e-01],
#         [-1.05880819e+00, -2.49327960e+00],
#         [-9.30375772e-02, -4.75486315e-01]],
#
#        [[ 1.03799161e+00,  9.70383483e-01],
#         [ 1.36317485e+00, -8.71018436e-01],
#         [-4.03140967e-01, -1.28692645e+00],
#         [ 1.50717062e-01,  1.01629283e+00]],
#
#        [[ 1.19907896e-01, -1.12038805e+00],
#         [-1.83587869e+00, -1.78791580e+00],
#         [-2.57592937e-01,  9.57666270e-01],
#         [-1.37610697e-01, -3.20636289e-01]],
#
#        [[-5.30584677e-02,  4.63919644e-01],
#         [ 7.45580332e-01, -6.02926980e-02],
#         [ 4.08679620e-01,  6.39457882e-01],
#         [ 7.97296914e-01,  9.61223120e-01]],
#
#        [[-6.04574448e-01, -1.56581552e-01],
#         [ 6.67459643e-01, -8.16016852e-01],
#         [-6.75963449e-01,  7.20074955e-01],
#         [ 9.36126344e-01,  3.21239385e-01]],
#
#        [[ 1.15278441e+00,  1.12336174e+00],
#         [-5.18076240e-01, -1.30757708e+00],
#         [ 1.63942490e+00, -1.53521404e+00],
#         [-4.22272370e-01,  1.61939568e+00]],
#
#        [[-1.52939651e+00,  5.28956817e-01],
#         [ 1.31636406e+00,  2.30788984e+00],
#         [-1.28368941e+00, -1.34863479e+00],
#         [ 3.68722639e-01, -1.13669474e+00]],
#
#        [[ 2.10959075e+00, -6.29406563e-01],
#         [-3.45455059e-02,  1.53434336e+00],
#         [ 5.31068747e-02, -1.66655731e+00],
#         [ 3.72660948e-01,  7.98498637e-01]],
#
#        [[-8.63520047e-01,  2.23329707e-01],
#         [-1.13998153e+00,  9.80048389e-01],
#         [ 9.57540086e-01, -1.12052862e+00],
#         [-3.03156413e-01,  3.79471269e-01]],
#
#        [[-5.43082670e-01, -7.57743440e-01],
#         [-2.06719347e+00, -1.18540555e+00],
#         [-8.35248832e-01, -3.35537518e+00],
#         [ 1.57756519e+00,  6.52852999e-01]],
#
#        [[-8.65231004e-01, -5.58940133e-01],
#         [ 8.22285100e-01,  3.96540667e-01],
#         [-4.07026509e-02,  7.79025316e-01],
#         [-2.28568276e-01,  4.69294108e-01]],
#
#        [[-1.35942001e+00, -1.29230219e+00],
#         [ 1.37620281e+00,  1.32161549e+00],
#         [-5.45342328e-01,  1.41094156e+00],
#         [ 1.25345235e+00, -1.31753525e+00]],
#
#        [[-1.12677649e+00,  3.67988600e-01],
#         [ 1.54123499e+00, -8.30283685e-01],
#         [ 5.83777786e-01, -5.54049547e-01],
#         [-8.37861412e-01,  7.58785732e-01]],
#
#        [[ 1.24829812e+00, -1.69497214e-02],
#         [ 9.97588551e-01, -6.67769881e-01],
#         [ 2.81180131e-01, -4.20248570e-01],
#         [-1.04710236e+00,  1.72404814e+00]],
#
#        [[-1.28752815e+00, -3.80533970e-01],
#         [-8.64871233e-01,  2.40821456e-01],
#         [-1.35297998e+00,  3.04919310e-01],
#         [-1.87413791e+00, -3.28310679e-01]],
#
#        [[-7.50786312e-01,  9.56285395e-01],
#         [ 4.87688204e-01, -1.35043261e-01],
#         [ 7.68974874e-01,  3.03305991e-01],
#         [-2.97388792e-01, -6.42582606e-01]],
#
#        [[ 5.61136448e-02,  1.06912641e+00],
#         [ 8.30106491e-02, -2.33620465e-01],
#         [ 1.85804634e-01, -9.08601311e-01],
#         [-1.84288947e+00, -7.92041800e-01]],
#
#        [[ 1.19293359e+00,  1.52546973e+00],
#         [ 2.72234515e+00,  8.38229710e-01],
#         [-1.94429713e+00, -4.37494096e-01],
#         [-2.78084466e-01, -2.61497404e-01]],
#
#        [[-1.16160465e+00,  3.32892365e-01],
#         [ 9.61511674e-01, -4.16333197e-01],
#         [ 2.53654877e-01,  6.90513734e-01],
#         [-4.92976679e-01,  1.24885450e+00]],
#
#        [[-2.92160096e-01,  1.93452732e-01],
#         [-5.62524045e-01, -5.32138702e-03],
#         [ 2.24932471e-01, -2.43208011e+00],
#         [-5.57413638e-01,  5.71821438e-01]],
#
#        [[-3.38170550e-01, -8.83843122e-02],
#         [-5.08353722e-01,  1.29229642e+00],
#         [-2.10063903e-01,  5.46460672e-01],
#         [ 6.54593060e-01,  4.18849988e-01]],
#
#        [[ 3.30989311e-01, -1.32200120e+00],
#         [ 5.87342406e-01,  1.22549927e+00],
#         [ 1.54459708e+00,  1.20383527e+00],
#         [-3.74634368e-01,  4.52977883e-01]],
#
#        [[ 1.34784256e+00,  4.57870716e-01],
#         [-6.70027668e-01,  7.86732595e-01],
#         [ 1.16809540e+00, -9.14422962e-01],
#         [ 7.20350525e-01, -1.85957043e+00]],
#
#        [[ 7.46561304e-01,  3.66529489e-01],
#         [ 1.60399216e+00,  1.69642050e+00],
#         [-1.19974457e+00,  9.04327918e-02],
#         [ 3.92679605e-01,  6.54984287e-02]],
#
#        [[-6.72181367e-01, -8.65916149e-01],
#         [-1.49808613e+00,  1.26572366e+00],
#         [ 8.83429693e-01,  3.90169956e-01],
#         [-1.02592109e+00, -3.56591316e-01]],
#
#        [[ 1.00189210e+00,  2.96214245e-01],
#         [ 1.52909685e+00,  5.81675677e-02],
#         [-1.16829731e+00, -3.81231469e-01],
#         [ 4.90012112e-02, -6.74117949e-01]],
#
#        [[ 6.09853952e-02,  1.86613411e+00],
#         [-7.33636396e-01, -9.98040001e-01],
#         [ 2.44873655e-01, -4.23065156e-01],
#         [-2.39441733e-01,  5.17259257e-01]],
#
#        [[ 5.77753698e-02,  2.54688806e+00],
#         [-2.40170811e-01, -3.30222264e-01],
#         [ 1.54603647e+00, -7.18147642e-01],
#         [-1.23659835e+00, -2.95994820e-01]],
#
#        [[ 6.62001947e-01, -4.32881454e-01],
#         [-2.13587433e+00,  3.95882724e-01],
#         [ 1.22581458e+00,  1.83615124e-01],
#         [-5.24403413e-01, -2.08360456e-01]],
#
#        [[ 4.73532883e-01,  7.74809647e-01],
#         [ 2.34372055e-02,  1.96725902e+00],
#         [-1.92574760e+00,  2.25542413e-01],
#         [ 5.09422262e-01, -6.47264571e-01]],
#
#        [[-1.78040702e+00,  1.41754515e+00],
#         [ 8.14475631e-02, -1.40950180e+00],
#         [ 4.89261834e-01,  4.59464007e-01],
#         [ 6.53057778e-01,  7.38131103e-02]],
#
#        [[-8.54275337e-01, -2.41384865e+00],
#         [-1.68159595e-01,  8.84657575e-01],
#         [-5.25476243e-01,  1.76446778e+00],
#         [ 1.89583887e+00, -2.58540030e-01]],
#
#        [[-8.74030800e-01,  7.87189840e-01],
#         [ 1.42646905e+00,  4.66829434e-02],
#         [-9.92364912e-01, -2.45340972e-01],
#         [ 9.11507491e-01, -7.53669812e-01]],
#
#        [[-6.73537767e-01, -5.40056813e-01],
#         [-1.08623655e+00,  1.89031158e-01],
#         [ 8.02387153e-01, -1.77795174e+00],
#         [-9.22508308e-01, -9.25983267e-01]],
#
#        [[ 2.84518199e-01, -3.55981785e-01],
#         [ 1.06904180e-01, -1.30801178e+00],
#         [-8.90614258e-01,  7.27407599e-01],
#         [-4.55771304e-01, -2.02017445e-01]],
#
#        [[ 9.03926670e-01,  1.14234325e+00],
#         [-1.23591387e-01, -8.22039321e-01],
#         [ 2.48544992e+00,  1.89011500e+00],
#         [-1.11213714e+00,  1.47331684e+00]],
#
#        [[-3.73572631e-01, -3.73944465e-01],
#         [-1.25062413e+00,  5.17522286e-01],
#         [-3.24507119e-01,  3.29804375e-01],
#         [ 2.42270214e+00, -2.04819371e-01]],
#
#        [[-1.61839220e-01,  7.65518016e-02],
#         [-7.44781470e-01,  1.91066793e-01],
#         [ 2.23756767e-01,  1.38126489e+00],
#         [ 5.83324096e-01, -8.56016281e-01]],
#
#        [[ 7.61656514e-01, -1.28825369e+00],
#         [ 4.85444540e-02, -3.73019657e-01],
#         [-2.76317365e-01, -1.86467461e+00],
#         [ 1.91174252e+00,  1.21112457e+00]],
#
#        [[-1.57948376e+00,  7.54149960e-01],
#         [-1.80636319e+00,  2.32578250e-01],
#         [ 3.34379469e-01,  2.39105021e-01],
#         [ 6.94387598e-01, -3.23702710e-01]],
#
#        [[ 1.14254892e+00,  4.51602999e-01],
#         [-1.19235609e+00, -1.43680108e+00],
#         [-4.17316664e-01,  3.15223916e-01],
#         [-1.34316212e+00,  9.41035043e-01]],
#
#        [[-1.73718890e+00, -5.41691545e-01],
#         [-2.24221882e+00, -6.60279300e-01],
#         [ 1.11291260e+00,  1.56337854e-01],
#         [ 2.28657212e-01,  3.56592184e-01]],
#
#        [[-6.32405591e-01,  1.47762936e+00],
#         [ 2.40228127e-01, -1.10396669e-01],
#         [-8.65710016e-02,  1.31942891e+00],
#         [-2.42800377e-01,  1.17993375e+00]],
#
#        [[ 2.54442152e-01,  1.74789291e-01],
#         [ 4.07222429e-01, -8.77707352e-01],
#         [ 9.37843138e-01, -1.73902574e+00],
#         [ 7.02452608e-02,  6.98281541e-01]],
#
#        [[ 7.96041837e-01,  1.59318462e+00],
#         [-2.36516091e+00, -6.64329779e-01],
#         [ 3.64914106e-01, -9.81792999e-02],
#         [ 5.57072127e-01,  2.95318534e+00]],
#
#        [[-3.09063011e-01, -3.51602821e-02],
#         [-9.08701140e-01,  2.39606660e+00],
#         [ 3.53293081e-01, -2.30205078e-01],
#         [ 4.12286215e-02, -1.83162223e-01]],
#
#        [[ 1.63682918e+00, -4.34012642e-01],
#         [ 7.00033383e-01,  4.77725358e-01],
#         [-7.07723892e-01,  1.82893892e+00],
#         [-1.18740017e-01,  6.92144754e-01]],
#
#        [[ 2.40690852e+00,  1.59130371e+00],
#         [ 3.28773862e-01, -1.23659934e+00],
#         [-1.57511117e+00, -1.65474300e+00],
#         [ 3.62725227e-01,  1.23181642e-01]],
#
#        [[ 9.22666508e-01, -1.63044612e-01],
#         [-8.80729407e-01, -8.36689676e-01],
#         [-5.36907133e-01,  1.05483417e+00],
#         [ 2.95217956e-01, -8.04462224e-01]],
#
#        [[-9.06068738e-02,  9.41816781e-02],
#         [ 1.01053410e+00, -5.32487802e-01],
#         [-2.30244970e-01, -2.08367992e+00],
#         [ 9.20375034e-01, -1.88409783e-01]],
#
#        [[ 1.31117073e-01,  1.35614708e-01],
#         [ 8.89313240e-01, -1.04938916e+00],
#         [-2.41488747e+00,  8.74332279e-01],
#         [ 2.48397409e-01,  6.48190886e-01]],
#
#        [[ 2.13715056e-01,  5.64900506e-01],
#         [ 4.40102566e-01, -9.45667907e-01],
#         [-4.49695254e-01, -2.18009439e-01],
#         [-7.79962288e-01,  8.27137785e-01]],
#
#        [[-4.43602500e-01,  1.07003636e+00],
#         [-1.25515532e+00, -4.98528435e-01],
#         [ 8.77223300e-02,  3.39531131e-01],
#         [ 1.03689895e+00, -1.35493490e+00]],
#
#        [[-3.32975594e-01, -1.40797536e-01],
#         [-1.03400808e+00, -8.63725125e-01],
#         [-7.44661980e-01,  4.55421840e-01],
#         [ 1.23229396e+00, -7.91032676e-01]],
#
#        [[ 1.09381767e-01, -1.01931504e+00],
#         [-1.08661682e-01, -1.04741188e+00],
#         [ 1.44822589e-01, -6.78637300e-01],
#         [ 2.22930174e-01, -4.89456010e-01]],
#
#        [[-1.29696127e+00, -3.38677881e-01],
#         [-5.28367135e-01, -3.10009915e-01],
#         [ 1.39156725e+00, -1.24062538e-01],
#         [-9.19582581e-01, -6.85907688e-01]],
#
#        [[ 1.03072836e-01,  4.20727048e-01],
#         [ 1.23118560e+00, -1.79488293e+00],
#         [ 3.56438895e-01,  8.31845090e-01],
#         [ 8.82270532e-01,  3.57702357e-02]],
#
#        [[ 1.77947574e+00,  1.24273421e+00],
#         [ 2.61164777e-03, -5.39707685e-01],
#         [ 5.08296100e-01,  1.91118152e+00],
#         [ 1.48725201e-01, -1.41721588e+00]],
#
#        [[-1.10834825e+00,  5.44291768e-03],
#         [-3.77492758e-01, -1.90263269e-01],
#         [ 4.65668256e-01,  9.88747417e-01],
#         [-1.49508990e+00, -1.07065979e+00]],
#
#        [[-6.64194597e-01, -9.03604780e-01],
#         [ 9.41538978e-01, -3.09750738e-01],
#         [ 2.53465782e-01, -1.69874339e+00],
#         [-1.53585821e+00, -2.70469962e-01]],
#
#        [[-7.52820509e-01, -9.97540087e-01],
#         [-1.42852935e-01, -1.21230972e-01],
#         [ 1.16139531e+00, -9.73468660e-01],
#         [-1.63682360e-01,  1.89929671e-01]],
#
#        [[ 8.17408586e-01, -4.49948963e-01],
#         [ 7.40966728e-01, -6.15208229e-01],
#         [-2.28084653e-01,  4.20767805e-01],
#         [ 4.80534801e-01, -1.50265092e+00]],
#
#        [[-2.09647705e-01,  3.47059777e-01],
#         [ 9.01543081e-02, -7.32219013e-02],
#         [ 3.12016976e-01,  2.25780175e-01],
#         [ 1.79212947e+00,  2.45514349e-01]],
#
#        [[-2.65471656e-01, -1.35575745e+00],
#         [-1.05823206e+00,  5.11602091e-01],
#         [ 6.49741826e-01,  1.58344547e+00],
#         [ 2.14015428e+00, -2.28597615e-01]],
#
#        [[ 9.79485602e-01,  2.26882045e+00],
#         [-4.15177853e-03,  1.36763169e+00],
#         [-1.33867358e+00,  1.20674962e+00],
#         [-9.23758822e-01,  7.76623596e-01]],
#
#        [[ 9.74050457e-01,  7.39323319e-02],
#         [-8.17542099e-01, -1.49835012e+00],
#         [-3.13592636e-01, -1.57869360e+00],
#         [-1.12078906e+00,  1.21880364e+00]],
#
#        [[-1.73680908e+00,  1.30421397e-01],
#         [ 1.41271455e+00,  2.15346350e+00],
#         [ 8.39927560e-01,  1.56841656e-01],
#         [-9.84293714e-01, -2.83421057e-01]],
#
#        [[ 5.63022341e-01, -6.64992665e-01],
#         [ 1.14624368e+00, -7.98122846e-01],
#         [ 1.21983180e+00, -2.76742677e-01],
#         [ 4.17247715e-02,  1.30058354e+00]],
#
#        [[-4.64490449e-02,  1.08679581e+00],
#         [-4.38555443e-01,  3.91521190e-01],
#         [-4.02502650e-01,  1.86587962e-01],
#         [ 1.41641678e-01,  1.32127098e+00]],
#
#        [[-1.22513149e-01,  1.36701468e-01],
#         [-5.95529138e-01, -1.09366844e+00],
#         [ 1.23196492e+00, -9.97767439e-01],
#         [ 1.44084573e-01, -9.08210320e-01]],
#
#        [[-2.92176596e-03, -1.79448210e-01],
#         [-1.17894485e+00, -2.05674867e-02],
#         [-6.73104078e-02,  9.03544773e-01],
#         [ 3.50214226e-01,  9.76467472e-01]],
#
#        [[-1.32011654e+00,  7.39880556e-01],
#         [-1.98499924e-01, -3.76066098e-01],
#         [ 1.16342513e-01,  1.57381676e+00],
#         [ 1.71751185e-01, -8.32651941e-01]],
#
#        [[-9.21035893e-01,  6.83871907e-01],
#         [-5.52261176e-02,  1.25569103e+00],
#         [ 6.65187544e-01, -2.03328050e-02],
#         [-6.55549277e-01,  4.78392716e-01]],
#
#        [[-1.50587409e-01, -4.13716601e-01],
#         [-2.10308564e+00,  5.53277061e-01],
#         [ 9.16774801e-02,  2.12400315e+00],
#         [-1.64439099e+00,  1.52685669e-02]],
#
#        [[-3.91661843e-01, -1.91178719e+00],
#         [-2.07743120e-02,  5.88859389e-01],
#         [-1.35474000e+00, -1.47863383e+00],
#         [ 9.81699517e-01, -6.12848098e-01]],
#
#        [[-9.39227363e-01, -1.82348177e+00],
#         [ 6.85047049e-01,  2.03977900e+00],
#         [-1.73589228e-01,  4.77489769e-01],
#         [-3.28965525e-01,  7.32053782e-01]],
#
#        [[ 1.20085836e+00, -4.60226114e-01],
#         [ 8.24635529e-01, -3.71129674e-01],
#         [ 6.69294090e-01,  1.69018696e+00],
#         [ 2.87961783e-01, -2.08176447e-01]],
#
#        [[ 7.73375475e-02, -1.07677282e+00],
#         [-9.11949260e-01,  1.74125685e+00],
#         [ 7.01295762e-01,  8.27609726e-01],
#         [ 1.07894557e+00,  5.09536308e-01]],
#
#        [[ 1.58431175e+00, -1.88467775e-01],
#         [ 6.16399773e-01,  1.44992271e+00],
#         [ 3.40846227e-02, -1.46821936e+00],
#         [-2.68730822e+00,  9.39731548e-01]],
#
#        [[ 1.48183656e-01, -1.28153512e+00],
#         [ 9.85804531e-01, -9.96944217e-01],
#         [ 1.29486174e+00,  1.42021178e+00],
#         [-7.71306281e-01, -5.47046303e-01]],
#
#        [[ 7.85592896e-02,  1.15607644e+00],
#         [-2.24579799e-01,  8.96993855e-01],
#         [ 1.26587838e+00,  2.26378900e+00],
#         [ 1.64879509e-01, -2.18155913e-01]],
#
#        [[ 5.84817104e-01, -6.70903773e-01],
#         [-5.90123380e-01, -1.63319530e+00],
#         [-1.80824088e+00, -1.66939517e-01],
#         [-4.25316639e-01, -2.99778346e-01]]])

# %% [markdown]
# Vous pouvez accéder à la documentation de la fonction avec *Shit+tab*. Pour plus d'information, cliquez sur le +. Testez avec la fonction numpy.random.randn.

# %% [markdown]
# Testez le code suivant et comprenez-le :

# %%
X = 0.1*np.random.randn(100,4,2)+np.array([[0,0],[0,1],[1,0],[1,1]])

for i in range(4):
    plt.scatter(X[:,i,0],X[:,i,1],c='rgby'[i])

plt.show()

# %% [markdown]
# 1 - Visualisation des données (Matplotlib)<a id="title1.3"></a>
# -----

# %% [markdown]
# `Matplotlib` permet de construire une figure à visualiser. La création d'une figure ce fait à l'aide de l'instruction `plt.figure`. Toutes les instructions que l'on fait ensuite agissent sur la figure courante en mémoire mais ne sont pas directement visibles. Afin de rendre effectivement visible la figure finale, on utilise l'instruction `plt.show`. Cette instruction est bloquante en python standard.
# Testez le code suivant affichant un `sinus` et un `cosinus`.

# %%
x = torch.linspace(0,2*np.pi,100) # création de 100 points entre 0 et 2pi
plt.figure() # Création d'une figure
plt.plot(x,torch.sin(x)) # Ajout du tracé d'un sinus composé de 100 points reliés par des droites entre 0 et 2pi
plt.plot(x,torch.cos(x)) # Ajout du tracé d'un cosinus composé de 100 points reliés par des droites entre 0 et 2pi
plt.show() # Affichage de la figure créée.

# %% [markdown]
# Regardez le code suivant. Il permet de tracer la fonction sinus en rouge en mettant des carrés (square == s) aux points vraiment calculés et en les reliant par une droite. Le deuxième tracé est la fonction sinus en bleu, seul les points sous la forme d'étoile sont tracés.

# %%
x = torch.linspace(0,2*np.pi,10)

plt.figure(figsize=(12,12)) # définition d'une figure en précisant sa taille

# Courbes
plt.plot(x,torch.sin(x),'rs-',label='Sinus')
plt.plot(x,torch.cos(x),'b*',label='Cosinus')

# Titre et légende
plt.title('Comparaison Sinus/Cosinus entre 0 et $2\pi$')
plt.legend()

# Texte des axes
plt.xlabel('Abscisse')
plt.ylabel('Ordonnée')

# Définition des limites des axes
plt.xlim([-1,7])
plt.ylim([-2,2])

plt.show() # Affichage de la figure créée.

# %% [markdown]
# Attention l'ordre des points est important si on souhaite les reliés:

# %%
x = np.linspace(0,2*np.pi,100)

plt.figure(figsize=(12,12))

np.random.shuffle(x)
plt.plot(x,np.sin(x),'*-')
plt.plot(x,np.cos(x),'+')

plt.show()

# %% [markdown]
# Faites une figure affichant à la fois la fonction sinus cardinal de $x$ ($sinc(x)=\dfrac{sin(x)}{x}$) et l'inverse de x. Vous mettrez la fonction inverse en pointillé. Vous ajouterez également un titre et une légende.

# %%
X = np.linspace(-2*np.pi, 2*np.pi, 100)
plt.figure()
plt.title('Fonction sinc et fonction inverse')
plt.ylabel("Ordonnées")
plt.xlabel("Abscisses")
plt.plot(X, np.sinc(X))
plt.plot(X, 1/X, '+')
plt.show()

# %% [markdown]
# La fonction `plt.scatter` permet d'afficher spécifiquement des points qui ne seront pas reliés. Elle permet notamment d'afficher des points de couleurs et tailles différentes.

# %%
t = np.linspace(0,2*np.pi,10)
plt.figure()
plt.scatter(np.cos(t),np.sin(t),c=t,s=100*t)
plt.axis('equal') # pour avoir des axes avec les mêmes proportions.
plt.colorbar() # Échelle des valeurs associées aux couleurs 

#cbar = plt.colorbar(ticks=[0,np.pi,2*np.pi])
#cbar.ax.set_yticklabels(["Low","Medium","High"])

plt.show()

# %% [markdown]
# La fonction `plt.imshow` permet d'afficher un tableau comme une image. Les valeurs doivent être soit entières entre 0 et 255 soit flottantes entre 0. et 1. .

# %%
n=int(1e3)
x = np.linspace(0,1,n)
degradee = np.tile(x[:,np.newaxis],n)

im = np.stack((degradee,degradee.T,1-degradee),axis=2)

plt.figure()
plt.imshow(im)
plt.show()

# %% [markdown]
# Si le tableau est une matrice, l'image sera affichée en fausse couleurs correspondant à la carte de couleur paramétrée. Pour avoir une image en noir et blanc, il faudra préciser `cmap='gray'`.

# %%
plt.figure()
plt.imshow(degradee)
plt.colorbar()

plt.figure()
plt.imshow(degradee,cmap='gray')
plt.colorbar()

plt.show()

# %% [markdown]
# 2 - Décomposition d'une image à l'aide d'ondelette de Haar
# ----

# %% [markdown]
# Commencez par importer l'image sur lequel nous allons travailler à l'aide de l'instruction suivante:

# %%
im = plt.imread('ada.png')
#im = plt.imread('ada_color_1844_400x400.jpg')/255

# %% [markdown]
# Affichez l'image avec matplotlib.

# %%
plt.imshow(im)
plt.show()

# %% [markdown]
# Convertissez l'image en `Tensor` Pytorch.

# %%
imtensor = torch.tensor(im)
print(imtensor.size())
# Out:
# torch.Size([214, 217, 4])

# %% [markdown]
# L'image que vous avez chargée est considéré comme une image couleur, les trois canaux sont identiques. Gardez uniquement un seul canal.

# %%
onetensor = imtensor[:, :, 0]
print("Anciennes dimensions de l'image: ", imtensor.size())
print("Nouvelles dimensions de l'image: ", onetensor.size())
# Out:
# Anciennes dimensions de l'image:  torch.Size([214, 217, 4])
# Nouvelles dimensions de l'image:  torch.Size([214, 217])

# %% [markdown]
# L'image fait actuellement 214x217. Tronquez l'image pour ne garder que les 200 premières lignes et colonnes.

# %%
trunctensor = onetensor[:200, :200]
print("Anciennes dimensions de l'image: ", onetensor.size())
print("Nouvelles dimensions de l'image: ", trunctensor.size())
# Out:
# Anciennes dimensions de l'image:  torch.Size([214, 217])
# Nouvelles dimensions de l'image:  torch.Size([200, 200])

# %% [markdown]
# Appliquez un `average pooling` sur l'image en utilisant la fonction se trouvant dans `torch.nn.functional` . Faites en sortes que la nouvelle image soit quatre fois plus petite que la précédente.

# %%
im_avg = torch.nn.functional.avg_pool2d(trunctensor[None, None, :, :], 4)
print("Dimensions de im_avg: ", im_avg.size())
# Out:
# Dimensions de im_avg:  torch.Size([1, 1, 50, 50])

# %% [markdown]
# Affichez l'image de la question précédente. Quel a eu comme effet sur l'image l'application de la couche d' `average pooling` ?

# %%
plt.figure(figsize = (10, 10))
plt.imshow(im_avg[0][0], cmap='gray')
plt.show()

# %% [raw]
# Effet sur l'image : l'effet obtenu est un floutage semblable au floutage gaussien , l'image devient plus flou car elle a ete moyennee

# %% [markdown]
# Effectuez maintenant un `average pooling` en moyennant uniquement les colonnes de l'image deux par deux.

# %%
im_avg2 = torch.nn.functional.avg_pool2d(trunctensor[None, None, :, :], (1, 2))
print("Dimensions de im_avg2: ", im_avg2.size())
plt.figure(figsize = (10, 10))
plt.imshow(im_avg2[0][0], cmap = 'gray')
plt.show()
# Out:
# Dimensions de im_avg2:  torch.Size([1, 1, 200, 100])

# %% [markdown]
# Déclarez un vecteur contenant deux 1 que vous nommerez `f`. Faites en sortes que les dimensions de `f` soit (1,2).

# %%
f = torch.ones((1,2))
print("f = ", f)
print("Dimensions de f: ", f.size())
# Out:
# f =  tensor([[1., 1.]])
# Dimensions de f:  torch.Size([1, 2])

# %% [markdown]
# Faites une convolution entre l'image et le filtre `f` avec un `stride` de 1 sur les lignes et 2 sur les colonnes. Vous utiliserez la fonction se trouvant dans `torch.nn.functional`.
#
# Expliquez pourquoi on obtient un résultat similaire à l'utilisation d'un `average pooling` à un facteur près.

# %%
im_conv1 = torch.nn.functional.conv2d(trunctensor[None, None, :, :], f[None, None ,: , :], stride = (1, 2))
print("Dimensions de im_conv1: ", im_conv1.size())

plt.figure(figsize = (10, 10))
plt.imshow(im_conv1[0][0], cmap = 'gray')
plt.show()
# Out:
# Dimensions de im_conv1:  torch.Size([1, 1, 200, 100])

# %% [raw]
# On obtient un résultat similaire à celui avec un `average pooling` car le produit de convolution fait la somme x[i][j] + x[i][j+1] et le stride permet de diviser le nombre de colonnes en 2.

# %% [markdown]
# En utilisant un filtre de convolution bien choisi. Calculez l'image tel que chaque pixel correspond au calcul de $x_{i,j}-x_{i+1,j}$ où $x_{i,j}$ est le pixel de la ligne $i$, colonne $j$.

# %%
f2 = torch.FloatTensor([[1], [-1]])
im_conv2 = torch.nn.functional.conv2d(trunctensor[None, None, :, :], f2[None, None, : , :], stride = (1, 2))

plt.figure(figsize = (10, 10))
plt.imshow(im_conv2[0][0], cmap = 'gray')
plt.show()

# %% [markdown]
# En construisant un filtre approprié, faites en sortes d'utiliser une seule convolution pour produire les deux images précédentes en même temps. Le résultat de chacune des convolutions correspondra à un canal. Vous appellerez le tenseur de sortie `im_out1` et le noyau utilisé `k_colonne`.

# %%
k_colonne = torch.FloatTensor([[-1,1],[1,1]])

im_out1 = torch.nn.functional.conv2d(trunctensor[None,None,:,:], k_colonne[:,None,None,:],stride = (1,2))

# %% [markdown]
# Affichez `im_out1` en deux images.

# %%
plt.figure(figsize = (10, 10))
plt.subplot(1, 2, 1)
plt.imshow(im_out1[0][0], cmap = 'gray')
plt.subplot(1, 2, 2)
plt.imshow(im_out1[0][1], cmap = 'gray')
plt.show()

# %% [markdown]
# L'une des images correspond à l'application d'un filtre passe bas sur les colonnes et l'autre à un filtre passe haut. Expliquez quelle image est associé à quel filtre et pourquoi.

# %% [raw]
# Explication: celle de gauche est un filtre passe haut et celle de droite est un filtre passe bas.

# %% [markdown]
# En utilisant un `reshape` approprié, affichez les deux canaux de `im_out1` concaténer sur les lignes en une image. Les valeurs des images n'ayant pas la même dynamique et n'étant pas entre 0 et 1, le rendu sera différent des questions précédentes, il ne vous est pas demandé de corriger le rendu.

# %%
im_out2 = torch.cat((im_out1[0,0,:,:],im_out1[0,1,:,:]),0)
plt.figure(figsize=(20,20))
plt.imshow(im_out2,cmap='gray')

# %% [markdown]
# En utilisant la fonction `torch.transpose` en plus de la fonction `reshape`, concaténez les deux canaux sur les colonnes et affichez l'image obtenue.

# %%
im_out3 = torch.cat((im_out1[0,0,:,:],im_out1[0,1,:,:]),1)
print(im_out3.shape)
plt.figure(figsize=(20,10))
plt.imshow(im_out3,cmap='gray')
# Out:
# torch.Size([200, 200])

# %% [markdown]
# Définissez maintenant un noyau permettant de faire les deux filtrages précédent sur les lignes et non sur les colonnes. Appelez ce noyau `k_ligne`.

# %%
m = torch.ones((1,2))
m[0][1]=-1

k_ligne = torch.cat((f,m),0)
#k_ligne = torch.transpose(k_ligne,0,1)
print(k_ligne)
# Out:
# tensor([[ 1.,  1.],
#         [ 1., -1.]])

# %% [markdown]
# Appliquez le noyau de convolution de la question précédente avec un `stride` adapté pour faire maintenant un filtrage passe base et passe haut selon les lignes.

# %%
im_out2 = torch.nn.functional.conv2d(trunctensor[None,None,:,:],k_ligne[:,None,None,:],None,[2,1])
print(im_out2.shape)

plt.figure(figsize=(10,10))
plt.imshow(im_out2[0,0,:,:],cmap='gray')
plt.figure(figsize=(10,10))
plt.imshow(im_out2[0,1,:,:],cmap='gray')
# Out:
# torch.Size([1, 2, 100, 199])

# %% [markdown]
# Concaténez `k_ligne` avec lui-même selon les lignes pour avoir un noyau `k_ligne2` de dimension `4,2`.

# %%
k_ligne2=torch.cat((k_ligne,k_ligne),0)
print('Dimensions de k_ligne2',k_ligne2.shape)
print(k_ligne2)
# Out:
# Dimensions de k_ligne2 torch.Size([4, 2])
# tensor([[ 1.,  1.],
#         [ 1., -1.],
#         [ 1.,  1.],
#         [ 1., -1.]])

# %% [markdown]
# Utilisez le noyau `k_ligne2` sur `im_out1`. Le résultat s'appellera `im_out2`. Changez le `stride` pour vous déplacer de 2 en 2 sur les lignes et de 1 en 1 sur les colonnes. Vous mettrez également l'argument `groups` à 2 et vous expliquerez l'intérêt de cette opération.

# %%
im_out2 = torch.nn.functional.conv2d(im_out1,k_ligne2[:,None,None,:],None,[2,1],groups=2)
print(im_out2.shape)
# Out:
# torch.Size([1, 4, 100, 99])

# %% [markdown]
# Affichez les 4 canaux obtenus dans la question précédente. Expliquez à quoi correspond chacun de ces canaux en termes de filtrage. Ces 4 images correspondent à la décomposition par ondelette de Haar de l'image initiale.

# %%
fig = plt.figure(figsize=(15,15))
fig.add_subplot(2,2,1)
plt.imshow(im_out2[0,0,:,:],cmap='gray')
fig.add_subplot(2,2,2)
plt.imshow(im_out2[0,1,:,:],cmap='gray')
fig.add_subplot(2,2,3)
plt.imshow(im_out2[0,2,:,:],cmap='gray')
fig.add_subplot(2,2,4)
plt.imshow(im_out2[0,3,:,:],cmap='gray')
plt.show()

# %% [markdown]
# 3 - Retrouver une transformation à partir de l'image générée
# ---

# %% [markdown]
# Afin de construire la décomposition en ondelette nous avons dans la question précédente appliqué deux convolutions successives. Le graphe de calcul que nous avons mis en place est de type image -> convolution 1 -> convolution 2 . L'enchainement de deux convolutions peut être facilement simplifié en une seule convolution (que l'on appellera convolution 12). Nous allons faire comme si on ne connaissait pas les noyaux de deux convolutions et on va essayer de retrouver la valeur du noyau utilisé pour convolution 12 à partir de l'image source et de l'image produite.

# %% [markdown]
# En utilisant une classe se trouvant `torch.nn` déclarez un objet `conv12` qui permettra d'appliquer une convolution à une image. Le noyau utilisé sera de taille 2x2 avec un `stride` de 2 et il ne faudra pas utiliser de biais

# %%
conv12 = torch.nn.Conv2d(1,4,kernel_size=(2,2),stride=2,bias=False)

# %% [markdown]
# Regardez la valeur du noyau que contient la couche `conv12` (elle se trouve dans l'attribut `weight`). Cette valeur a été choisie aléatoirement et changera à chaque lancement.

# %%
print('Valeur:',conv12.weight)
# Out:
# Valeur: Parameter containing:
# tensor([[[[-0.0578,  0.1255],
#           [ 0.1148, -0.4449]]],
#
#
#         [[[-0.1565,  0.3895],
#           [-0.4259, -0.4318]]],
#
#
#         [[[ 0.1945,  0.4683],
#           [-0.0667,  0.2339]]],
#
#
#         [[[ 0.2581, -0.4990],
#           [ 0.0621, -0.4413]]]], requires_grad=True)

# %% [markdown]
# Appliquez la couche de convolution `conv12` à l'image initiale et visualisez le résultat.

# %%
out = conv12(trunctensor[None,None,:,:])
print(out.shape)
print(type(out[0,0,:,:]))
fig = plt.figure(figsize=(10,10))
fig.add_subplot(2,2,1)
plt.imshow(out[0,0,:,:].detach().numpy(),cmap='gray')
fig.add_subplot(2,2,2)
plt.imshow(out[0,1,:,:].detach().numpy(),cmap='gray')
fig.add_subplot(2,2,3)
plt.imshow(out[0,2,:,:].detach().numpy(),cmap='gray')
fig.add_subplot(2,2,4)
plt.imshow(out[0,3,:,:].detach().numpy(),cmap='gray')
plt.show()
# Out:
# torch.Size([1, 4, 100, 100])
# <class 'torch.Tensor'>

# %% [markdown]
# En utilisant une fonction de coût de type MSE (Mean Squared Error) calculer l'écart entre le tenseur de sortie de `conv12` et `im_out2`.

# %%
loss_func = torch.nn.MSELoss()
print('Valeur de la fonction de coût:',loss_func(out[:,:,:,:99],im_out2))
# Out:
# Valeur de la fonction de coût: tensor(1.4757, grad_fn=<MseLossBackward0>)

# %% [markdown]
# Appliquez la rétropropagation du gradient et affichez les valeurs de gradient pour les paramètres de la convolution.

# %%
# Out:
# Valeur de $\dfrac{\partial\ \text{loss}}{\partial w}$:
# tensor([[[[-1.0343, -1.0296],
#           [-1.0332, -1.0288]]],
#
#
#         [[[ 0.0989,  0.0981],
#           [ 0.1013,  0.1005]]],
#
#
#         [[[-0.3689, -0.3623],
#           [-0.3679, -0.3616]]],
#
#
#         [[[ 0.0294,  0.0307],
#           [ 0.0303,  0.0300]]]])

# %% [markdown]
# Mettez à jours la valeur du poids de la convolution en effectuant une étape de descente de gradient. Pour faire cela vous calculerez: $w \longleftarrow w - \alpha \dfrac{\partial\ \text{loss}}{\partial w}$ en prenant $\alpha=1$. Attention pour pouvoir faire cette opération vous devez désactiver temporairement l'utilisation du gradient dans le graphe.

# %% [markdown]
# Remettez à zéros les valeurs du gradient.

# %% [markdown]
# Refaites de même pour 500 itérations de descente de gradient

# %%
# Out:
# Fonction de coût après 10000 itérations: tensor(5.0836e-08, grad_fn=<MseLossBackward>)
# Noyau trouvé: Parameter containing:
# tensor([[[[ 1.0017,  0.9983],
#           [ 0.9983,  1.0018]]],
#
#
#         [[[ 0.9999,  1.0001],
#           [-0.9999, -1.0001]]],
#
#
#         [[[ 0.9991, -0.9991],
#           [ 1.0009, -1.0010]]],
#
#
#         [[[ 0.9932, -0.9931],
#           [-0.9931,  0.9929]]]], requires_grad=True)

# %% [markdown]
# À votre avis quel devrait être la valeur du noyau que nous cherchons ? Vérifiez que ces valeurs donnent le résultat attendu.

# %% [raw]
# Valeur du noyau :

# %%
# Out:
# Valeur de la fonction de coût avec le noyau optimal 3.5008343930888327e-15

# %% [markdown]
# 4 - Reconstruction d'une image à partir de sa décomposition en ondelette
# ---

# %% [markdown]
# Pour reconstruire l'image à partir de sa décomposition, vous devez utiliser l'opération inverse de celle faite précédemment. En utilisant l'opérateur de convolution transpose, reconstruisez l'image.

# %% [markdown]
# En utilisant la fonction `plt.hist` de `matplotlib`. Visualisez l'histogramme des valeurs de chaque canal de la décomposition. Vous utiliserez 100 `bins` pour chaque histogramme.

# %% [markdown]
# Que pouvez-vous dire sur la répartition des valeurs dans chaque canal ?

# %% [raw]
# Explication

# %% [markdown]
# En utilisant la fonction d'activation `hardshrink` appliquez un écrasement des valeurs entre -0.1 et 0.1 sur 0 du tenseur `im_out2`. Affichez les nouveaux histogrammes.

# %% [markdown]
# Calculez la proportion de valeurs à 0 dans cette représentation.

# %%
# Out:
# Proportion de valeur à 0 dans la décomposition initiale: 2.38%
# Proportion de valeur à 0 dans la décomposition modifiée: 66.68%

# %% [markdown]
# Reconstruisez l'image à partir de la décomposition modifiée de la question précédente. Comparez là à l'image initiale.

# %% [markdown]
# Comparez les reconstructions avec des valeurs différentes d'interval pour l'écrasement des valeurs de `im_out2`. Le mécanisme qui a été présenté ici est donné comme un exercice pédagogique pour vous faire comprendre avant tout le fonctionnement des opérateurs de Pytorch, ce n'est en aucun cas ce qu'il faut faire pour réaliser une vraie compression par ondelette.
